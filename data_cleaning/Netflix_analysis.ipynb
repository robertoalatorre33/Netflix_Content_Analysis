# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('netflix_titles.csv')
df.head(3)
# Out:
#   show_id     type            title      director  \
# 0    s366    Movie  Eyes of a Thief  Najwa Najjar
# 1    s194  TV Show             D.P.           NaN
# 2    s276  TV Show      The Kingdom           NaN
#
#                                                 cast            country  \
# 0  Khaled Abol El Naga, Souad Massi, Suhail Hadda...  , France, Algeria
# 1  Jung Hae-in, Koo Kyo-hwan, Kim Sung-kyun, Son ...      , South Korea
# 2  Chino Darín, Nancy Dupláa, Joaquín Furriel, Pe...          Argentina
#
#   date_added  release_year rating  duration  \
# 0  30-Jul-21          2014  TV-14   103 min
# 1  27-Aug-21          2021  TV-MA  1 Season
# 2  13-Aug-21          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 0   Dramas, Independent Movies, International Movies
# 1                  International TV Shows, TV Dramas
# 2  Crime TV Shows, International TV Shows, Spanis...
#
#                                          description
# 0  After a decade in prison, a Palestinian man wi...
# 1  A young private’s assignment to capture army d...
# 2  After his running mate's murder, a controversi...

# %% [markdown]
# ### Identifying and dealing with missing data
# - In this case, I will:
#   - Identify which columns have missing values
#   - Replace blank countries with the mode (most common) country
#   - I want to keep director as it could be interesting to look at a certain director's films
#   - I want to keep cast as it could be interesting to look at a certain cast's films

# %%
# Identyfing which columns have missing data

for i in df.columns:
    null_rate = df[i].isna().sum() / len(df) * 100 
    if null_rate > 0 :
        print("{} null rate: {}%".format(i,round(null_rate,2)))
# Out:
# director null rate: 29.91%
# cast null rate: 9.37%
# country null rate: 9.44%
# date_added null rate: 0.11%
# rating null rate: 0.05%
# duration null rate: 0.03%

# %%
#Replacements


df['country'] = df['country'].fillna(df['country'].mode()[0])

df['cast'].replace(np.nan, 'No Data',inplace  = True)
df['director'].replace(np.nan, 'No Data',inplace  = True)

#Drop columns with missing values
df.dropna(inplace=True)

#Drop Duplicates
df.drop_duplicates(inplace = True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.info()

# %%
df.loc[0,'country']='France'
df.loc[1,'country']='South Korea'

# %% [markdown]
# ### Dealing with dates
# - I will convert the dates data type to date time

# %%
#Converted the date data types to date time and created additional columns for month and year for additional analysis

df["date_added"] = pd.to_datetime(df['date_added'])
df['month_added']=df['date_added'].dt.month
df['month_name_added']=df['date_added'].dt.month_name()
df['year_added'] = df['date_added'].dt.year

df.head(1)
# Out:
#   show_id   type            title      director  \
# 0    s366  Movie  Eyes of a Thief  Najwa Najjar
#
#                                                 cast date_added  release_year  \
# 0  Khaled Abol El Naga, Souad Massi, Suhail Hadda... 2021-07-30          2014
#
#   rating duration                                         listed_in  \
# 0  TV-14  103 min  Dramas, Independent Movies, International Movies
#
#                                          description  month_added  \
# 0  After a decade in prison, a Palestinian man wi...          7.0
#
#   month_name_added  year_added target_ages first_country
# 0             July      2021.0       Teens        France

# %%
df.set_index('show_id', inplace = True)

# %%
#Created categories for target age groups 

ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}

df['target_ages'] = df['rating'].replace(ratings_ages)

df.head(1)
# Out:
#   show_id   type            title      director  \
# 0    s366  Movie  Eyes of a Thief  Najwa Najjar
#
#                                                 cast country date_added  \
# 0  Khaled Abol El Naga, Souad Massi, Suhail Hadda...  France 2021-07-30
#
#    release_year rating duration  \
# 0          2014  TV-14  103 min
#
#                                           listed_in  \
# 0  Dramas, Independent Movies, International Movies
#
#                                          description  month_added  \
# 0  After a decade in prison, a Palestinian man wi...          7.0
#
#   month_name_added  year_added target_ages
# 0             July      2021.0       Teens

# %%
# Split the 'country' column using the ',' delimiter and create a new DataFrame
split_df = df['country'].str.split(',', expand=True)

# Assign the first element to a new column 'first_country'
df['first_country'] = split_df[0]

# Drop the original 'country' column if needed
df.drop(columns=['country'], inplace=True)

df.head(1)
# Out:
#   show_id   type            title      director  \
# 0    s366  Movie  Eyes of a Thief  Najwa Najjar
#
#                                                 cast date_added  release_year  \
# 0  Khaled Abol El Naga, Souad Massi, Suhail Hadda... 2021-07-30          2014
#
#   rating duration                                         listed_in  \
# 0  TV-14  103 min  Dramas, Independent Movies, International Movies
#
#                                          description  month_added  \
# 0  After a decade in prison, a Palestinian man wi...          7.0
#
#   month_name_added  year_added target_ages first_country
# 0             July      2021.0       Teens        France

# %%
# Split the 'country' column using the ',' delimiter and create a new DataFrame
#split_df = df['listed_in'].str.split(',', expand=True)

# Assign the first element to a new column 'first_country'
#df['category1,category2'] = split_df[0]

# Drop the original 'country' column if needed
#df.drop(columns=['country'], inplace=True)

df.head(1)
# Out:
#           type            title      director  \
# show_id
# s366     Movie  Eyes of a Thief  Najwa Najjar
#
#                                                       cast date_added  \
# show_id
# s366     Khaled Abol El Naga, Souad Massi, Suhail Hadda... 2021-07-30
#
#          release_year rating duration  \
# show_id
# s366             2014  TV-14  103 min
#
#                                                 listed_in  \
# show_id
# s366     Dramas, Independent Movies, International Movies
#
#                                                description  month_added  \
# show_id
# s366     After a decade in prison, a Palestinian man wi...          7.0
#
#         month_name_added  year_added target_ages first_country  \
# show_id
# s366                July      2021.0       Teens        France
#
#          movie_duration  tv_show_seasons
# show_id
# s366              103.0              NaN

# %%
# Function to extract duration in minutes from the 'duration'
def extract_duration(row):
    if pd.notna(row['duration']) and 'min' in row['duration']:
        duration = row['duration'].split(' min')[0]
        return int(duration)
    return None

# Apply the function to create the 'movie_duration' column
df['movie_duration'] = df.apply(extract_duration, axis=1)

df.head(1)
# Out:
#   show_id   type            title      director  \
# 0    s366  Movie  Eyes of a Thief  Najwa Najjar
#
#                                                 cast            country  \
# 0  Khaled Abol El Naga, Souad Massi, Suhail Hadda...  , France, Algeria
#
#   date_added  release_year rating duration  \
# 0  30-Jul-21          2014  TV-14  103 min
#
#                                           listed_in  \
# 0  Dramas, Independent Movies, International Movies
#
#                                          description  movie_duration
# 0  After a decade in prison, a Palestinian man wi...           103.0

# %%
# Function to extract duration in minutes from the 'tv_show_seasons'
def extract_duration(row):
    if pd.notna(row['duration']) and 'Season' in row['duration']:
        duration = row['duration'].split(' Season')[0]
        return int(duration)
    return None

# Apply the function to create the 'movie_duration' column
df['tv_show_seasons'] = df.apply(extract_duration, axis=1)

df.head(1)
# Out:
#           type            title      director  \
# show_id
# s366     Movie  Eyes of a Thief  Najwa Najjar
#
#                                                       cast date_added  \
# show_id
# s366     Khaled Abol El Naga, Souad Massi, Suhail Hadda... 2021-07-30
#
#          release_year rating duration  \
# show_id
# s366             2014  TV-14  103 min
#
#                                                 listed_in  \
# show_id
# s366     Dramas, Independent Movies, International Movies
#
#                                                description  month_added  \
# show_id
# s366     After a decade in prison, a Palestinian man wi...          7.0
#
#         month_name_added  year_added target_ages first_country  \
# show_id
# s366                July      2021.0       Teens        France
#
#          movie_duration  tv_show_seasons
# show_id
# s366              103.0              NaN
